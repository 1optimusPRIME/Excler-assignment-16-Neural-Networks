# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, KFold
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam
from keras.layers import Dropout

# %%
gas=pd.read_csv('gas_turbines.csv')
gas.head()
# Out:
#        AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0  6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1  6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2  6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3  7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4  7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
#
#        CO     NOX
# 0  3.1547  82.722
# 1  3.2363  82.776
# 2  3.2012  82.468
# 3  3.1923  82.670
# 4  3.2484  82.311

# %%
gas=gas.iloc[:,[7,0,1,2]]

# %%
gas.shape
# Out:
# (15039, 4)

# %%
gas.describe()
# Out:
#                 TEY            AT           AP            AH
# count  15039.000000  15039.000000  15039.00000  15039.000000
# mean     134.188464     17.764381   1013.19924     79.124174
# std       15.829717      7.574323      6.41076     13.793439
# min      100.170000      0.522300    985.85000     30.344000
# 25%      127.985000     11.408000   1008.90000     69.750000
# 50%      133.780000     18.186000   1012.80000     82.266000
# 75%      140.895000     23.862500   1016.90000     90.043500
# max      174.610000     34.929000   1034.20000    100.200000

# %%
gas.isnull().sum()
# Out:
# TEY    0
# AT     0
# AP     0
# AH     0
# dtype: int64

# %%
x=gas.iloc[:,1:5]
y=gas.iloc[:,0]

# %%
x
# Out:
#            AT      AP      AH
# 0      6.8594  1007.9  96.799
# 1      6.7850  1008.4  97.118
# 2      6.8977  1008.8  95.939
# 3      7.0569  1009.2  95.249
# 4      7.3978  1009.7  95.150
# ...       ...     ...     ...
# 15034  9.0301  1005.6  98.460
# 15035  7.8879  1005.9  99.093
# 15036  7.2647  1006.3  99.496
# 15037  7.0060  1006.8  99.008
# 15038  6.9279  1007.2  97.533
#
# [15039 rows x 3 columns]

# %%
y
# Out:
# 0        114.70
# 1        114.72
# 2        114.71
# 3        114.72
# 4        114.72
#           ...
# 15034    111.61
# 15035    111.78
# 15036    110.19
# 15037    110.74
# 15038    111.58
# Name: TEY, Length: 15039, dtype: float64

# %%
seed=7
np.random.seed(seed)

# %%
model=Sequential()
model.add(Dense(12, input_dim=3,  kernel_initializer='uniform', activation='relu'))
model.add(Dense(8,  kernel_initializer='uniform', activation='relu'))
model.add(Dense(1,  kernel_initializer='uniform', activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history=model.fit(x,y,validation_split=0.33,epochs=150,batch_size=10)
# Out:
# Epoch 1/150
# Epoch 148/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -2912191512576.0000 - accuracy: 0.0000e+00 - val_loss: -2869207498752.0000 - val_accuracy: 0.0000e+00
# Epoch 149/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -2969157763072.0000 - accuracy: 0.0000e+00 - val_loss: -2925167116288.0000 - val_accuracy: 0.0000e+00
# Epoch 150/150
# 1008/1008 [==============================] - 4s 4ms/step - loss: -3026856706048.0000 - accuracy: 0.0000e+00 - val_loss: -2981805162496.0000 - val_accuracy: 0.0000e+00

# %%
scores = model.evaluate(x, y)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 470/470 [==============================] - 1s 2ms/step - loss: -3031500587008.0000 - accuracy: 0.0000e+00
# accuracy: 0.00%

# %%
import matplotlib.pyplot as plt
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
a=StandardScaler()
a.fit(x)
X_standardized=a.transform(x)

# %%
pd.DataFrame(X_standardized).describe()
# Out:
#                   0             1             2
# count  1.503900e+04  1.503900e+04  1.503900e+04
# mean   4.913654e-16 -1.875504e-14  2.570219e-16
# std    1.000033e+00  1.000033e+00  1.000033e+00
# min   -2.276462e+00 -4.266288e+00 -3.536594e+00
# 25%   -8.392292e-01 -6.706510e-01 -6.796337e-01
# 50%    5.566605e-02 -6.227861e-02  2.277844e-01
# 75%    8.051309e-01  5.772924e-01  7.916582e-01
# max    2.266234e+00  3.275970e+00  1.528011e+00

# %%
def create_model():
    model = Sequential()
    model.add(Dense(12, input_dim=3, kernel_initializer='uniform', activation='relu'))
    model.add(Dense(8, kernel_initializer='uniform', activation='relu'))
    model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))

    adam=Adam(lr=0.01)
    model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
    return model

# %%
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means= grid_result.cv_results_['mean_test_score']
stds=grid_result.cv_results_['std_test_score']
params=grid_result.cv_results_['params']
for mean, stdev,param in zip(means,stds,params):
    print('{},{}with: {}'.format(mean,stdev,param))
# Out:
# Best : 0.0, using {'batch_size': 10, 'epochs': 10}
# 0.0,0.0with: {'batch_size': 10, 'epochs': 10}
# 0.0,0.0with: {'batch_size': 10, 'epochs': 50}
# 0.0,0.0with: {'batch_size': 10, 'epochs': 100}
# 0.0,0.0with: {'batch_size': 20, 'epochs': 10}
# 0.0,0.0with: {'batch_size': 20, 'epochs': 50}
# 0.0,0.0with: {'batch_size': 20, 'epochs': 100}
# 0.0,0.0with: {'batch_size': 40, 'epochs': 10}
# 0.0,0.0with: {'batch_size': 40, 'epochs': 50}
# 0.0,0.0with: {'batch_size': 40, 'epochs': 100}

# %%
def create_model(learning_rate,dropout_rate):
    model = Sequential()
    model.add(Dense(8,input_dim = 3,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(4,input_dim = 3,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = learning_rate)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# %%
model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)
# Define the grid search parametars
learning_rate = [0.001,0.01,0.1]
dropout_rate = [0.0,0.1,0.2]
# Make a dictionary of the grid search parameters 
param_grids = dict(learning_rate = learning_rate,dropout_rate = dropout_rate)
#build and fit the GridSearchCV
grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# C:\Users\91832\AppData\Local\Temp\ipykernel_17132\200409313.py:1: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)
# [CV 1/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=0.000 total time=   6.1s
# [CV 2/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 2/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=0.000 total time=   6.0s
# [CV 3/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 3/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=0.000 total time=   6.0s
# [CV 4/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 4/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=0.000 total time=   6.1s
# [CV 5/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 5/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=0.000 total time=   6.1s
# [CV 1/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# [CV 1/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=0.000 total time=   6.1s
# [CV 2/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# [CV 2/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=0.000 total time=   6.0s
# [CV 3/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# [CV 3/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=0.000 total time=   5.2s
# [CV 4/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# [CV 4/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=0.000 total time= 5.6min
# [CV 5/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# [CV 5/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=0.000 total time=   3.7s
# [CV 1/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# [CV 1/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=0.000 total time=   5.8s
# [CV 2/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# [CV 2/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=0.000 total time=   6.1s
# [CV 3/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# [CV 3/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=0.000 total time=   6.0s
# [CV 4/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# [CV 4/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=0.000 total time=   6.0s
# [CV 5/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# [CV 5/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=0.000 total time=   6.1s
# [CV 1/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# [CV 1/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=0.000 total time=  11.2s
# [CV 2/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# [CV 2/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=0.000 total time=  11.2s
# [CV 3/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# [CV 3/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=0.000 total time=   6.4s
# [CV 4/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# [CV 4/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=0.000 total time=   6.4s
# [CV 5/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# [CV 5/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=0.000 total time=  11.2s
# [CV 1/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 1/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=0.000 total time=   6.4s
# [CV 2/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 2/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=0.000 total time=   6.5s
# [CV 3/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 3/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=0.000 total time=  11.6s
# [CV 4/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 4/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=0.000 total time=  11.3s
# [CV 5/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 5/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=0.000 total time=  11.3s
# [CV 1/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 1/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=0.000 total time=  11.3s
# [CV 2/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 2/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=0.000 total time=  11.3s
# [CV 3/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 3/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=0.000 total time=  11.2s
# [CV 4/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 4/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=0.000 total time=  11.2s
# [CV 5/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 5/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=0.000 total time=  11.3s
# [CV 1/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# [CV 1/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=0.000 total time=   6.5s
# [CV 2/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# [CV 2/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=0.000 total time=  11.3s
# [CV 3/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# [CV 3/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=0.000 total time=  53.2s
# [CV 4/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# [CV 4/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=0.000 total time=   5.5s
# [CV 5/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# [CV 5/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=0.000 total time=   6.3s
# [CV 1/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 1/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=0.000 total time=   6.6s
# [CV 2/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 2/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=0.000 total time=   6.0s
# [CV 3/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 3/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=0.000 total time=  11.3s
# [CV 4/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 4/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=0.000 total time=   6.2s
# [CV 5/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 5/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=0.000 total time=   6.4s
# [CV 1/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 1/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=0.000 total time=  11.3s
# [CV 2/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 2/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=0.000 total time=   5.9s
# [CV 3/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 3/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=0.000 total time=  11.3s
# [CV 4/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 4/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=0.000 total time=  11.3s
# [CV 5/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 5/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=0.000 total time=  11.4s

# %%
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means=grid_result.cv_results_['mean_test_score']
stds=grid_result.cv_results_['std_test_score']
params=grid_result.cv_results_['params']
for mean,stdev,param in zip(means,stds,params):
    print('{},{}with:{}'.format(mean,stdev,param))
# Out:
# Best : 0.0, using {'dropout_rate': 0.0, 'learning_rate': 0.001}
# 0.0,0.0with:{'dropout_rate': 0.0, 'learning_rate': 0.001}
# 0.0,0.0with:{'dropout_rate': 0.0, 'learning_rate': 0.01}
# 0.0,0.0with:{'dropout_rate': 0.0, 'learning_rate': 0.1}
# 0.0,0.0with:{'dropout_rate': 0.1, 'learning_rate': 0.001}
# 0.0,0.0with:{'dropout_rate': 0.1, 'learning_rate': 0.01}
# 0.0,0.0with:{'dropout_rate': 0.1, 'learning_rate': 0.1}
# 0.0,0.0with:{'dropout_rate': 0.2, 'learning_rate': 0.001}
# 0.0,0.0with:{'dropout_rate': 0.2, 'learning_rate': 0.01}
# 0.0,0.0with:{'dropout_rate': 0.2, 'learning_rate': 0.1}

# %%
def create_model(neuron1,neuron2):
    model = Sequential()
    model.add(Dense(neuron1,input_dim = 3,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(neuron2,input_dim = neuron1,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = 0.001)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# %%
model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)
# Define the grid search parameters
neuron1 = [4,8,16]
neuron2 = [2,4,8]
# Make a dictionary of the grid search parameters
param_grids = dict(neuron1 = neuron1,neuron2 = neuron2)
# Build and fit the GridSearchCV
grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START neuron1=4, neuron2=2........................................
# C:\Users\91832\AppData\Local\Temp\ipykernel_17132\2627903290.py:1: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)
# [CV 1/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.000 total time=   6.4s
# [CV 2/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 2/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.000 total time=  11.2s
# [CV 3/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 3/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.000 total time=  11.3s
# [CV 4/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 4/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.000 total time=   6.7s
# [CV 5/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 5/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.000 total time=  11.3s
# [CV 1/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 1/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.000 total time=  11.3s
# [CV 2/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 2/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.000 total time=   6.3s
# [CV 3/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 3/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.000 total time=  11.2s
# [CV 4/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 4/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.000 total time=   6.2s
# [CV 5/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 5/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.000 total time=   6.4s
# [CV 1/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 1/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.000 total time=  11.1s
# [CV 2/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 2/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.000 total time=  11.2s
# [CV 3/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 3/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.000 total time=  11.3s
# [CV 4/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 4/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.000 total time=   6.4s
# [CV 5/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 5/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.000 total time=   6.5s
# [CV 1/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 1/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.000 total time=   6.4s
# [CV 2/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 2/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.000 total time=   6.5s
# [CV 3/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 3/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.000 total time=   6.7s
# [CV 4/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 4/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.000 total time=  11.2s
# [CV 5/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 5/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.000 total time=   6.5s
# [CV 1/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 1/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.000 total time=  11.2s
# [CV 2/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 2/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.000 total time=  11.2s
# [CV 3/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 3/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.000 total time=  11.2s
# [CV 4/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 4/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.000 total time=  11.2s
# [CV 5/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 5/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.000 total time=  11.3s
# [CV 1/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 1/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.000 total time=   6.2s
# [CV 2/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 2/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.000 total time=   6.4s
# [CV 3/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 3/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.000 total time=  11.3s
# [CV 4/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 4/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.000 total time=   6.3s
# [CV 5/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 5/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.000 total time=  11.2s
# [CV 1/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 1/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.000 total time=  11.3s
# [CV 2/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 2/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.000 total time=  11.6s
# [CV 3/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 3/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.000 total time=  11.3s
# [CV 4/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 4/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.000 total time=   6.3s
# [CV 5/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 5/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.000 total time=  11.2s
# [CV 1/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 1/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.000 total time=  11.3s
# [CV 2/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 2/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.000 total time=   6.6s
# [CV 3/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 3/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.000 total time=   6.5s
# [CV 4/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 4/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.000 total time=  11.3s
# [CV 5/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 5/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.000 total time=   6.4s
# [CV 1/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 1/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.000 total time=  11.3s
# [CV 2/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 2/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.000 total time=   6.4s
# [CV 3/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 3/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.000 total time=  11.3s
# [CV 4/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 4/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.000 total time=  11.2s
# [CV 5/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 5/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.000 total time=   6.8s

# %%
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.0, using {'neuron1': 4, 'neuron2': 2}
# 0.0,0.0 with: {'neuron1': 4, 'neuron2': 2}
# 0.0,0.0 with: {'neuron1': 4, 'neuron2': 4}
# 0.0,0.0 with: {'neuron1': 4, 'neuron2': 8}
# 0.0,0.0 with: {'neuron1': 8, 'neuron2': 2}
# 0.0,0.0 with: {'neuron1': 8, 'neuron2': 4}
# 0.0,0.0 with: {'neuron1': 8, 'neuron2': 8}
# 0.0,0.0 with: {'neuron1': 16, 'neuron2': 2}
# 0.0,0.0 with: {'neuron1': 16, 'neuron2': 4}
# 0.0,0.0 with: {'neuron1': 16, 'neuron2': 8}

# %%
from sklearn.metrics import classification_report, accuracy_score
def create_model():
    model = Sequential()
    model.add(Dense(16,input_dim = 3,kernel_initializer = 'normal',activation = 'linear'))
    model.add(Dropout(0.1))
    model.add(Dense(8,input_dim = 3,kernel_initializer = 'normal',activation = 'linear'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'linear'))
    adam = Adam(lr = 0.01)
    #sgd = SGD(lr=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# %%
model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 100)
# Fitting the model
model.fit(X_standardized,y)
# Predicting using trained model
y_predict = model.predict(X_standardized)
# Printing the metrics
print(accuracy_score(y_predict.round(),y.round()))
# Out:
# C:\Users\91832\AppData\Local\Temp\ipykernel_17132\2987446259.py:1: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 100)
# 470/470 [==============================] - 1s 1ms/step
# 0.00013298756566261055
